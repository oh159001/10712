# %% [markdown]
# <a href="https://colab.research.google.com/github/oh159001/10712/blob/main/20260910.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 'hello'
b = 'world'
print(a+b)
print(a*3)
print(a<b)
print('h' in a)
print('wor'not in b)
# Out:
# helloworld
# hellohellohello
# True
# True
# False

# %%
a = 'hello python'
print(a[0])
print(a[6])
print(a[-1])
# Out:
# h
# p
# n

# %%
a = 'hello Python'
print(a[0:5])
print(a[6:])
print()

# %%
a = input()
print('20',a[0:2],'년',a[2:4],'월',a[4:6],'일')
# Out:
# 100612
# 20 10 년 06 월 12 일

# %%
a = input()
b = (a[::-1])
b.replace('a','3')
# Out:
# abcdef
# 'fedcb3'
