# %% [markdown]
# <a href="https://colab.research.google.com/github/oh159001/10712/blob/main/20260907.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from datetime import datetime,date,time
print(',<디데이(0-day) 프로그램>')
print()
year = int(input('연도를 입력하세요'))
month = int(input('월을 입력하세세요'))
day = int(input('일을 입력하세요'))
dt4 = date(year,month,day)
today = date.today()
dday = (dt4-today).days
print(f'{year}년 {month}월 {day}일은 {dday}일 남았습니다. ')
# Out:
# ,<디데이(0-day) 프로그램>
#
# 연도를 입력하세요2026
# 월을 입력하세세요5
# 일을 입력하세요3
# 2026년 5월 3일은 -127일 남았습니다.
