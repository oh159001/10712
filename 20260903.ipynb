# %% [markdown]
# <a href="https://colab.research.google.com/github/oh159001/10712/blob/main/20260903.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('재미있는 프로그래밍')
print(3+7)
print('3+7')
print(10,20,30,'정보','프로그래밍')
# Out:
# 재미있는 프로그래밍
# 10
# 3+7
# 10 20 30 정보 프로그래밍

# %%
print('한양공업고등학교','1학년','오동혁')
a,b = map(int,input('키/몸무계:').split())
print(a/(b*b)*10000)
# Out:
# 한양공업고등학교 1학년 오동혁
# 키/몸무계:65 170
# 22.49134948096886

# %%
a = 20
b = 50
print(f'현재 온도는 {a}도, 습도는{b}%입니다')
# Out:
# 현재 온도는 20도, 습도는50%입니다

# %%
c = 90
d = 3.141592
print(f'직각은 {c}도,원주율은{d:0.2f}입니다')
# Out:
# 직각은 90도,원주율은3.14입니다

# %%
print('동해물과',"\'백두산'이",'\n동해물과','\"백두산"이','\n마르고 닳도록','하느님이 보우하사','\n우리나라만세','무궁화 삼천리 화려강산','\n대한사람,','\"대한"','대한으로')
# Out:
# 동해물과 '백두산'이
# 동해물과 "백두산"이
# 마르고 닳도록 하느님이 보우하사
# 우리나라만세 무궁화 삼천리 화려강산
# 대한사람, "대한" 대한으로

# %%
print('품목\t\t가격\t\t갯수\n사과\t\t2000\t\t 8\n바나나\t\t3000\t\t 5')
# Out:
# 품목		가격		갯수
# 사과		2000		 8
# 바나나		3000		 5
