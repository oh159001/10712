# %% [markdown]
# <a href="https://colab.research.google.com/github/oh159001/10712/blob/main/20260921.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = (10,'t',[20,30,40])
b = (5,)
c = tuple(range(3))
red = (255,0,0)
print(a,type(a))
print(c,len(c))
print(a+b)
print(red*2)
print(a[1])
print(a[2][1:])
print(a.index('t'))
# Out:
# (10, 't', [20, 30, 40]) <class 'tuple'>
# (0, 1, 2) 3
# (10, 't', [20, 30, 40], 5)
# (255, 0, 0, 255, 0, 0)
# t
# [30, 40]
# 1
