# %% [markdown]
# <a href="https://colab.research.google.com/github/oh159001/10712/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = int(input('학번:'))
b = input('성명:')
c = input('소속:')
print('#####################################')
print()
print('\t* 학번:',a)
print('wt* 성명:',b)
print('\t* 소속:',c)
print('위사람은 본 학교의 학생임을 증명함.')
print()
print('###################################')
# Out:
# 학번:10800
# 성명:오동혁
# 소속:스마트 전자과
# #####################################
#
# 	*학번: 10800
# wt*성명: 오동혁
# 	*소속: 스마트 전자과
# 위사람은 본 학교의 학생임을 증명함.
#
# ###################################
